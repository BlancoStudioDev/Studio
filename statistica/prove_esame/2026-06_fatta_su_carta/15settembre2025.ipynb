# %% [markdown]
# ##### ESERCIZIO 1
# Siano date due variabili aleatorie indipendenti $X$ e $Y$ che seguono una distribuzione normale dove $\mu_X$ è il valore atteso di $X$ e $\mu_Y$ il valore atteso di $Y$, e dove $\sigma_X$ è la deviazione standard di $X$ e $\sigma_Y$ la deviazione standard di $Y$.
# Sia data $Z = X - Y$, rispondere alle seguenti domande:
# 1. $Z$ è una variabile aleatoria? Se sì, è discreta o continua? Motivare adeguatamente la risposta

# %% [markdown]
# # Scritto di Statistica e Analisi dei Dati — Giugno 2026
#
# ---
#
# ## Esercizio 1
#
# In questo esercizio considereremo la funzione
#
# $$f(x) = \frac{12}{a^4} \, x(a - x)^2 \, \mathbb{1}_{[0,a]}(x),$$
#
# dove $\mathbb{1}_A$ denota la funzione indicatrice dell'insieme $A$ e $a > 0$ è un parametro di $f$. Indicheremo inoltre con $X$ una variabile aleatoria avente $f$ come funzione di densità di probabilità, per un valore ignoto di $a$.
#
# **1.** Mostrate che, per ogni intero $n \geq 0$,
#
# $$I_n := \int_0^a x^n f(x) \, dx = \frac{24 \, a^n}{(n+2)(n+3)(n+4)}$$
#
# *(Suggerimento: conviene sviluppare $x^{n+1}(a-x)^2$ e integrare termine a termine.)*
#
# **2.** Mostrate che, per ogni $a > 0$, $f$ è una densità di probabilità.
#
# **3.** Tracciate in uno stesso riferimento cartesiano i grafici di $f$ per $a = 1$ e $a = 2$ (su foglio oppure scrivendo del codice), evidenziando tutte le informazioni che ritenete importanti e mettendo in rilievo il ruolo del parametro $a$.
#
# **4.** Il grafico ottenuto al punto precedente potrebbe suggerire che $X$ segue una distribuzione normale? Perché? Validate o refutate questa ipotesi.
#
# **5.** Calcolate il valore atteso di $X$, esprimendolo in funzione di $a$.
#
# **6.** Calcolate la varianza e la deviazione standard di $X$, esprimendole in funzione di $a$.
#
# **7.** Dimostrate che, indipendentemente dal valore di $a$, la funzione di ripartizione di $X$ ha la seguente forma analitica:
#
# $$F(x) = \begin{cases} 0 & \text{se } x < 0, \\ 6\!\left(\dfrac{x}{a}\right)^{\!2} - 8\!\left(\dfrac{x}{a}\right)^{\!3} + 3\!\left(\dfrac{x}{a}\right)^{\!4} & \text{se } 0 \leq x \leq a, \\ 1 & \text{se } x > a. \end{cases}$$
#
# ---
#
# ## Esercizio 2
#
# In questo esercizio considereremo una popolazione $X$ la cui distribuzione è la stessa dell'omonima variabile aleatoria introdotta nell'esercizio precedente, dove $a$ rappresenterà un parametro incognito. Per $n \in \mathbb{N}$ fissato, $X_1, \ldots, X_n$ indicheranno delle variabili aleatorie che descrivono un campione estratto da $X$.
#
# **1.** Spiegate perché la media campionaria $\bar{X}$ è uno stimatore **distorto** per il parametro $a$.
#
# **2.** Dovendo scegliere se applicare il metodo plug-in o il metodo della massima verosimiglianza per ottenere uno stimatore non distorto per $a$, quale opzione risulta più agevole? Perché?
#
# **3.** Applicate il metodo scelto al punto precedente e determinate uno stimatore $T$ che sia non distorto per $a$.
#
# **4.** Calcolate il bias e la varianza dello stimatore $T$ che avete proposto al punto precedente.
#
# **5.** Lo stimatore $T$ che avete proposto al punto 3 gode della proprietà di **consistenza in media quadratica**? Giustificate la vostra risposta.
#
# **6.** Utilizzando il teorema centrale del limite, determinate la distribuzione approssimata dello stimatore $T$ ottenuto al punto 3.
#
# **7.** Calcolate la probabilità dell'evento che si verifica quando l'errore (in valore assoluto) commesso usando $T$ per stimare $a$ è minore o uguale di 1, esprimendola in funzione di $a$, $n$ e della funzione di ripartizione $\Phi$ della distribuzione normale standard. Giustificate i passaggi e indicate eventuali approssimazioni necessarie.
#
# ---
#
# ## Esercizio 3
#
# Collegatevi al sito [upload.di.unimi.it](https://upload.di.unimi.it), selezionate l'esame di *Statistica e analisi dei dati* per l'appello odierno e scaricate il file `sessioni_A.csv`. Una piattaforma di streaming ha affidato a un fornitore esterno di analisi dati gli eventi registrati durante le sessioni di visione di un singolo episodio di una serie. Per ciascuna sessione il file riporta:
#
# - **id**: identificativo della sessione;
# - **dispositivo**: dispositivo usato (codificato come `'mobile'` oppure `'TV'`);
# - **eta**: età dello spettatore o della spettatrice;
# - **minuto**: tempo (a partire dall'inizio dell'episodio) in cui la visione è stata abbandonata, espresso in minuti;
# - **pubblicità**: secondi di pubblicità complessivamente visti durante la sessione.
#
# La durata complessiva $a$ dell'episodio non è stata comunicata al fornitore. In questo file il carattere `;` separa le colonne.
#
# **1.** Scrivete ed eseguite del codice che visualizzi su righe differenti il nome di ogni attributo unitamente al corrispondente numero di valori mancanti.
#
# **2.** Di che tipo è l'attributo *dispositivo*? Sulla base della risposta data, visualizzate la distribuzione di questo attributo fornendo sia una formulazione tabulare, sia un grafico, motivando le vostre scelte.
#
# **3.** Considerate l'attributo *minuto* e ripetete l'analisi svolta al punto precedente, valutando se debba essere fatta nello stesso modo oppure se debbano essere utilizzati strumenti diversi.
#
# **4.** Valutate l'ipotesi che vi sia una relazione tra gli attributi *minuto* e *pubblicità*, specificando eventualmente il tipo e la forza della relazione. Quali strumenti avete utilizzato per valutare questa ipotesi? Perché?
#
# **5.** Verificate se esistano delle righe nel dataset per le quali risulta che si sia vista pubblicità per un tempo superiore rispetto al tempo di fruizione. Nel caso ne esistano, cancellatele dal dataset e **d'ora in avanti lavorate solo su questa nuova versione dei dati.**
#
# **6.** Utilizzate uno strumento grafico che vi permetta di valutare se i valori dell'attributo *minuto* siano assimilabili a un campione estratto da una distribuzione normale, valutando i risultati ottenuti e motivando la scelta dello strumento.
#
# **7.** In realtà, l'attributo *minuto* dovrebbe essere ben descritto da una distribuzione analoga a quella studiata nell'Esercizio 1. Scegliete uno strumento che ha senso utilizzare per validare questa ipotesi e applicatelo, commentando i risultati.
#
# ---
#
# ## Esercizio 4
#
# I valori dell'attributo *minuto* nel dataset dell'esercizio precedente sono distribuiti su un supporto il cui estremo destro $a$ — la durata complessiva dell'episodio — non è noto, e il fornitore vuole stimare questo valore a partire dai soli istanti di abbandono.
#
# **1.** Sulla base della soluzione proposta per l'Esercizio 2, calcolate una stima $\hat{a}$ per $a$ (cioè per la durata dell'episodio, in minuti).
#
# **2.** Calcolate la probabilità che la stima ottenuta al punto precedente comporti un errore (in valore assoluto) minore o uguale di un minuto. Si tratta di un valore esatto o di un'approssimazione? Perché?
#
# **3.** Quante sessioni sarebbe necessario avere nel dataset per garantire che la probabilità calcolata al punto precedente sia maggiore o uguale di 0.99?
#
# **4.** Indichiamo con $X$ la variabile aleatoria che descrive il minuto di abbandono. Una sessione si considera **coinvolta** se la visione supera il minuto 20. Calcolate la frequenza di questo evento nel dataset e confrontatela con la probabilità $\mathbb{P}(X > 20)$, calcolata sostituendo al parametro $a$ la stima $\hat{a}$ ottenuta al punto 1. Commentate i risultati.
#
# **5.** Ipotizzando che vi sia indipendenza tra le sessioni di spettatori diversi, supponiamo che cinque persone guardino lo stesso episodio, e indichiamo con $Y$ la variabile aleatoria che conta quante delle loro sessioni sono coinvolte (cioè superano il minuto 20). Dite quale distribuzione segue $Y$ e calcolate le seguenti probabilità, esprimendo anche l'evento corrispondente in termini di $Y$:
#
#    a. tutte e cinque le sessioni sono coinvolte;
#    b. esattamente una tra esse è coinvolta;
#    c. al più una tra esse è coinvolta.
#
# **6.** Ipotizzando che vi sia indipendenza tra le diverse sessioni di una stessa persona, indichiamo con $Z$ la variabile aleatoria che conta il numero di sessioni **non coinvolte** (abbandono entro il minuto 20) prima della prima sessione coinvolta. Dite quale distribuzione segue $Z$ e calcolate, esprimendo anche l'evento corrispondente in termini di $Z$:
#
#    a. la probabilità che la prima sessione coinvolta sia tra le prime tre che la persona avvia;
#    b. il numero medio di sessioni non coinvolte che ci si attende prima della prima sessione coinvolta.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

dati = pd.read_csv('punteggi.csv', sep=';')

print(5/2 * dati.minuto.mean())

print(2*stats.norm.cdf(np.sqrt()/(np.sqrt(21/2)))-1)

print((np.sqrt(21)/2*stats.norm.ppf(1.99/2))**2)
# Out:
# 44.53484848484848
# 1.0
# 34.833207155361364

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

dati = pd.read_csv('punteggi.csv', sep=';')

print(dati.isnull().sum())
# Out:
# id             0
# dispositivo    0
# eta            8
# minuto         3
# pubblicita     5
# dtype: int64

# %%
print(dati.dispositivo.dtype)
print(dati.head())
print(dati.dispositivo.value_counts())

plt.pie(dati.dispositivo.value_counts())
plt.legend(["mobile", "TV"])
plt.show()
# Out:
# str
#    id dispositivo   eta  minuto  pubblicita
# 0   1      mobile  19.0   38.70       339.7
# 1   2          TV  14.0   24.65       314.9
# 2   3          TV  26.0   27.64       368.3
# 3   4      mobile  39.0   30.57       254.6
# 4   5          TV  50.0    3.43        27.7
# dispositivo
# mobile    172
# TV        128
# Name: count, dtype: int64

# %%
print(dati.minuto.dtype)
print(dati.head())

plt.hist(dati.minuto, bins=30)
plt.show()

# probabilmente all'esame era più normale come visualizzazione
# Out:
# float64
#    id dispositivo   eta  minuto  pubblicita
# 0   1      mobile  19.0   38.70       339.7
# 1   2          TV  14.0   24.65       314.9
# 2   3          TV  26.0   27.64       368.3
# 3   4      mobile  39.0   30.57       254.6
# 4   5          TV  50.0    3.43        27.7

# %%
print(dati.minuto.corr(dati.pubblicita))

plt.scatter(dati.minuto, dati.pubblicita)
plt.show()

# mi sembra proprio di si che ci sia una relazione tra le due componenti, a parte qualche outlier, la relazione è lineare e dorte al 50%,
# secondo l'indice di pearson, anceh se in realtà è abbastanza forte e spostata solo dagli outliers in pearson
# Out:
# 0.5261877403513266

# %%
print(dati[dati["minuto"] > dati["pubblicita"]])

# non c'è niente che è così fuori da essere oltre...
# Out:
# Empty DataFrame
# Columns: [id, dispositivo, eta, minuto, pubblicita]
# Index: []

# %%
plt.hist(dati.minuto, bins=50)
plt.axvline(dati.minuto.mean(), color="r")
plt.show()

# sembra abbastanza una normale

# %%
x = np.arange(-20, 20, 0.01)

a = 2

f_X = 12/a**4 * x * (a - x)**2

plt.plot(f_X)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

a = 1

x = np.arange(-20,20,0.1)
y = 12/a**4 * x * (a - x)**2

plt.scatter(x,y)

a = 2

x = np.arange(-20,20,0.1)
y = 12/a**4 * x * (a - x)**2

plt.scatter(x,y)

a = 0.001

x = np.arange(-20,20,0.1)
y = 12/a**4 * x * (a - x)**2

plt.scatter(x,y)

# %% [markdown]
# si potrebbe essere una distribuzione normale, con a che va a schiacciare la sinusoide o ad amplificarla

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 2. Calcolare il valore atteso di $Z$ esprimendolo in funzione di $\mu_X$ e $\mu_Y$, mostrando i passaggi

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 3. Calcolare la varianza di $Z$ esprimendola in funzione di $\sigma_X$ e $\sigma_Y$, mostrando i passaggi

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 4. La variabile aleatoria $Z$ segue una distribuzione normale? Motivare la risposta

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 5. Calcolare la funzione di ripartizione $F_Z(x)$ esprimendola in funzione dei parametri citati sopra e utilizzando $\phi$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 6. Tenendo conto che $\mu_X = 2$, $\mu_Y = 1$, $\sigma_X = 1$ e $\sigma_Y = 2$, disegnare il grafico della funzione di ripartizione di $Z$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 7. Calcolare la funzione di densità di probabilità $f_Z(x)$ esprimendola in funzione dei parametri sopracitati e utilizzando $\phi$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 8. Tenendo conto che $\mu_X = 2$, $\mu_Y = 1$, $\sigma_X = 2$ e $\sigma_Y = 2$, disegnare il grafico della funzione di densità di probabilità di $Z$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# ##### ESERCIZIO 2
# Siano $Z_1, \dots, Z_n$ variabili aleatorie che descrivono un campione estratto da $Z$, distribuito come l'omonima all'esercizio precedente
# 1. Considerando solo in questo punto che sia noto $\mu_X$ determinare uno stimatore non distorto $U$ che stimi $\mu_Y$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 2. Considerando solo in questo punto che $\sigma_X = \sigma_Y$ determinare uno stimatore non distorto $V$ che stimi $\sigma_X^2$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 3. Determinare se lo stimatore $U$ è consistente in media quadratica

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 4. È possibile fare lo stesso ragionamento per $V$? Se no motivare la risposta, altrimenti determinare se lo stimatore è consistente in media quadratica

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 5. Dato $\epsilon$, determinare la probabilità che lo stimatore $U$ presenti al più un errore di $\epsilon$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# ##### ESERCIZIO 3
# Collegatevi al sito upload.di.unimi.it, selezionate l'esame di _Statistica e analisi dei dati_ per l'appello odierno e scaricate il file `punteggi.csv`. Questo file contiene le seguenti informazioni, che descrivono una serie di incontri tra due giocatori, $X$ e $Y$, ai quali tre arbitri A, B e C hanno dato dei punteggi:
# - `differenza`: è la differenza dei punteggi di $X$ è $Y$ assegnati in quell'incontro;
# - `arbitro`: indica l'arbitro che ha assegnato i punti nella partita;
# - `temperatura`: indica la temperatura durante l'incontro.
# 1. Descrivere i dati e determinarne i tipi

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 2. Si ha il sospetto che l'arbitro A abbia un pregiudizio sul giocatore $X$, determinare un indice che consenta di confermare o confutare questa ipotesi

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 3. Determinare se è presente un qualche tipo di influenza tra la temperatura e la differenza dei punteggi

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 4. Stabilire se temperatura segue una distribuzione normale

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 5. I punteggi dati dagli arbitri sono disomogenei, trovare un indice che consenta di confermare o confutare questa ipotesi (?)

# %% [markdown]
# **Soluzione**

# %% [markdown]
# ##### ESERCIZIO 4
# Prendendo in considerazione che `differenza` sia distribuito come $Z$
# 1. Sapendo che $\mu_X = 5$ calcolare una stima di $\mu_Y$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 2. Calcolare una stima per $\sigma_X^2$ evidenziando le proprietà dello stimatore

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 3. Calcolare $\sqrt{\sigma_X^2 + \sigma_Y^2}$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 4. Calcolare la probabilità che si verifichi un errore al più di 0.2 nella stima di $\mu_Y$

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 5. Determinare se sono presenti valori nulli in `differenza`

# %% [markdown]
# **Soluzione**

# %% [markdown]
# 6. Utilizzando le stime fatte negli esercizi precedenti per sostituire i valori nulli, calcolare le seguenti probabilità
#     1. Che X vinca contro Y
#     2. Che X batta Y almeno 3 volte su 10
#     3. Che X batta Y almeno 3 volte sapendo che X ne ha vinte almeno 2
#     4. Che X vinca dopo almeno 3 sconfitte
#     5. Che X vinca dopo almeno 3 sconfitte sapendo che Y ha vinto la prima

# %% [markdown]
# **Soluzione**
